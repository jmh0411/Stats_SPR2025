# %% [markdown]
# <a href="https://colab.research.google.com/github/jmh0411/Stats_SPR2025/blob/main/W05_4_20202505_%EC%9E%A5%EB%AA%85%ED%98%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import re, os
#os.chdir(r'C:/content/sample_data/apt2308.csv')

# %%
df = pd.read_csv('apt2308.csv', thousands=',')
df
# Out:
#                    시군구     번지    본번  부번            단지명    전용면적    계약년월  계약일  \
# 0      강원특별자치도 강릉시 견소동    202   202   0           송정한신  59.800  202308    8
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신  84.945  202308   14
# 2      강원특별자치도 강릉시 견소동    202   202   0           송정한신  43.380  202308   30
# 3      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  59.990  202308   19
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  84.990  202308   22
# ...                ...    ...   ...  ..            ...     ...     ...  ...
# 26504     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  66.957  202308   16
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  84.803  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대  84.960  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)  84.680  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임  84.950  202308   21
#
# ...

# %%
df =pd.read_csv('apt2308.csv', encoding = 'utf-8', thousands= ',')
df
# Out:
#                    시군구     번지    본번  부번            단지명    전용면적    계약년월  계약일  \
# 0      강원특별자치도 강릉시 견소동    202   202   0           송정한신  59.800  202308    8
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신  84.945  202308   14
# 2      강원특별자치도 강릉시 견소동    202   202   0           송정한신  43.380  202308   30
# 3      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  59.990  202308   19
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  84.990  202308   22
# ...                ...    ...   ...  ..            ...     ...     ...  ...
# 26504     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  66.957  202308   16
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  84.803  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대  84.960  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)  84.680  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임  84.950  202308   21
#
# ...

# %%
df.head()
# Out:
#                시군구   번지   본번  부번           단지명    전용면적    계약년월  계약일   거래금액  \
# 0  강원특별자치도 강릉시 견소동  202  202   0          송정한신  59.800  202308    8  23000
# 1  강원특별자치도 강릉시 견소동  202  202   0          송정한신  84.945  202308   14  31000
# 2  강원특별자치도 강릉시 견소동  202  202   0          송정한신  43.380  202308   30  16400
# 3  강원특별자치도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트  59.990  202308   19  24500
# 4  강원특별자치도 강릉시 견소동  289  289   0  송정해변신도브래뉴아파트  84.990  202308   22  28500
#
#     층    건축년도           도로명  해제사유발생일 등기신청일자  거래유형 중개사소재지
# 0   9  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 1  13  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 2  10  1997.0   경강로2539번길 8      NaN         중개거래    강릉시
# 3   5  2005.0  경강로2539번길 23      NaN         중개거래    강릉시
# 4   4  2005.0  경강로2539번길 22      NaN         중개거래    강릉시

# %%
df.tail()
# Out:
#                 시군구     번지    본번  부번            단지명    전용면적    계약년월  계약일  \
# 26504  충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  66.957  202308   16
# 26505  충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  84.803  202308   19
# 26506  충청북도 충주시 호암동  547-6   547   6           호반현대  84.960  202308   12
# 26507  충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)  84.680  202308   10
# 26508  충청북도 충주시 호암동   1191  1191   0        호암힐데스하임  84.950  202308   21
#
#         거래금액   층    건축년도        도로명  해제사유발생일 등기신청일자  거래유형  중개사소재지
# 26504  34100  15  2019.0  호암수청2로 78      NaN         중개거래  충북 충주시
# 26505  41000  12  2019.0  호암수청2로 78      NaN         중개거래  충북 충주시
# 26506  15700   2  1994.0    신촌2길 29      NaN         중개거래  충북 충주시
# 26507  20700   3  2002.0   호암중앙2로 5      NaN         중개거래  충북 충주시
# 26508  40200  11  2019.0   호암토성2로 1      NaN         중개거래  충북 충주시

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26509 entries, 0 to 26508
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   시군구      26509 non-null  object
#  1   번지       26509 non-null  object
#  2   본번       26509 non-null  object
#  3   부번       26509 non-null  int64
#  4   단지명      26509 non-null  object
#  5   전용면적     26509 non-null  float64
#  6   계약년월     26509 non-null  int64
#  7   계약일      26509 non-null  int64
#  8   거래금액     26509 non-null  int64
#  9   층        26509 non-null  int64
#  10  건축년도     26497 non-null  float64
#  11  도로명      26509 non-null  object
#  12  해제사유발생일  486 non-null    float64
#  13  등기신청일자   26509 non-null  object
#  14  거래유형     26509 non-null  object
#  15  중개사소재지   26509 non-null  object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 3.2+ MB

# %%
df['시군구']
# Out:
# 0        강원특별자치도 강릉시 견소동
# 1        강원특별자치도 강릉시 견소동
# 2        강원특별자치도 강릉시 견소동
# 3        강원특별자치도 강릉시 견소동
# 4        강원특별자치도 강릉시 견소동
#               ...
# 26504       충청북도 충주시 호암동
# 26505       충청북도 충주시 호암동
# 26506       충청북도 충주시 호암동
# 26507       충청북도 충주시 호암동
# 26508       충청북도 충주시 호암동
# Name: 시군구, Length: 26509, dtype: object

# %%
print(df[df['전용면적']>80])
# Out:
#                    시군구     번지    본번  부번            단지명      전용면적    계약년월  계약일  \
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신   84.9450  202308   14
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   22
# 5      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   29
# 6       강원특별자치도 강릉시 교동   1982  1982   0    강릉교동롯데캐슬1단지  163.9852  202308    4
# 7       강원특별자치도 강릉시 교동   1983  1983   0    강릉교동롯데캐슬2단지   84.9855  202308   17
# ...                ...    ...   ...  ..            ...       ...     ...  ...
# 26502     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8090  202308    4
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8030  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대   84.9600  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)   84.6800  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임   84.9500  202308   21
#
# ...

# %%
cond = df['전용면적']>80
df[cond]
# Out:
#                    시군구     번지    본번  부번            단지명      전용면적    계약년월  계약일  \
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신   84.9450  202308   14
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   22
# 5      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   29
# 6       강원특별자치도 강릉시 교동   1982  1982   0    강릉교동롯데캐슬1단지  163.9852  202308    4
# 7       강원특별자치도 강릉시 교동   1983  1983   0    강릉교동롯데캐슬2단지   84.9855  202308   17
# ...                ...    ...   ...  ..            ...       ...     ...  ...
# 26502     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8090  202308    4
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8030  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대   84.9600  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)   84.6800  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임   84.9500  202308   21
#
# ...

# %%
df[df['전용면적']>80]
# Out:
#                    시군구     번지    본번  부번            단지명      전용면적    계약년월  계약일  \
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신   84.9450  202308   14
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   22
# 5      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   29
# 6       강원특별자치도 강릉시 교동   1982  1982   0    강릉교동롯데캐슬1단지  163.9852  202308    4
# 7       강원특별자치도 강릉시 교동   1983  1983   0    강릉교동롯데캐슬2단지   84.9855  202308   17
# ...                ...    ...   ...  ..            ...       ...     ...  ...
# 26502     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8090  202308    4
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8030  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대   84.9600  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)   84.6800  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임   84.9500  202308   21
#
# ...

# %%
cond
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4         True
#          ...
# 26504    False
# 26505     True
# 26506     True
# 26507     True
# 26508     True
# Name: 전용면적, Length: 26509, dtype: bool

# %%
df[['단지명', '거래금액']][df['전용면적']>80]
# Out:
#                  단지명   거래금액
# 1               송정한신  31000
# 4       송정해변신도브래뉴아파트  28500
# 5       송정해변신도브래뉴아파트  32500
# 6        강릉교동롯데캐슬1단지  60000
# 7        강릉교동롯데캐슬2단지  37500
# ...              ...    ...
# 26502  충주호암두진하트리움아파트  41800
# 26505  충주호암두진하트리움아파트  41000
# 26506           호반현대  15700
# 26507     호암리버빌(2단지)  20700
# 26508        호암힐데스하임  40200
#
# [12306 rows x 2 columns]

# %%
df['단지명'][(df['전용면적']>130) & (df['거래금액']<30000)]
# Out:
# 140       현대5차
# 256       레이크뷰
# 370      라이프타운
# 392       현대3차
# 407         두산
#          ...
# 25655       건영
# 25657       건영
# 25840       신라
# 25891     세원홍실
# 26016       동아
# Name: 단지명, Length: 74, dtype: object

# %%
df.loc[:10 , ['단지명', '거래금액']][df['거래금액']>100000]
# Out:
# <ipython-input-32-6a4d1c60717b>:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df.loc[:10 , ['단지명', '거래금액']][df['거래금액']>100000]
# Empty DataFrame
# Columns: [단지명, 거래금액]
# Index: []
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['index']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'index'}, axis=1)
#               .sort_values('index', ascending=True))
#   xs = counted['index']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# ...

# %%
print(df.loc[:, ['단지명', '거래금액']][df['거래금액']>100000])
# Out:
#                       단지명    거래금액
# 1191            DMC디에트르한강  129000
# 1192           DMC한강에일린의뜰  130000
# 1193           DMC한강에일린의뜰  115000
# 1446             일산요진와이시티  155000
# 1449             일산요진와이시티  102000
# ...                   ...     ...
# 20912         송도센트럴파크푸르지오  101000
# 20913        송도아메리칸타운아이파크  121000
# 20933          송도자이하버뷰2단지  160000
# 24887  천안 불당 지웰시티푸르지오 2단지  105000
# 24895            천안불당지웰더샵  110000
#
# [1229 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적', '계약년월', '계약일', '거래금액', '층',
#        '건축년도', '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지'],
#       dtype='object')

# %%
df['단가'] = df['거래금액'] / df['전용면적']

# %%
df
# Out:
#                    시군구     번지    본번  부번            단지명    전용면적    계약년월  계약일  \
# 0      강원특별자치도 강릉시 견소동    202   202   0           송정한신  59.800  202308    8
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신  84.945  202308   14
# 2      강원특별자치도 강릉시 견소동    202   202   0           송정한신  43.380  202308   30
# 3      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  59.990  202308   19
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트  84.990  202308   22
# ...                ...    ...   ...  ..            ...     ...     ...  ...
# 26504     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  66.957  202308   16
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트  84.803  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대  84.960  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)  84.680  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임  84.950  202308   21
#
# ...

# %%
df.sort_values(by='거래금액', ascending=False)
# Out:
#                     시군구       번지    본번   부번      단지명     전용면적    계약년월  계약일  \
# 17714   서울특별시 성동구 성수동1가  685-696   685  696   갤러리아포레  217.860  202308   11
# 16292     서울특별시 강남구 도곡동      467   467    0   타워팰리스1  244.660  202308    5
# 17622     서울특별시 서초구 반포동      757   757    0  반포주공1단지  140.130  202308    2
# 16297     서울특별시 강남구 도곡동   467-29   467   29   타워팰리스3  244.224  202308   18
# 17619     서울특별시 서초구 반포동    20-43    20   43     반포자이  244.972  202308    2
# ...                 ...      ...   ...  ...      ...      ...     ...  ...
# 22609  전라북도 익산시 낭산면 용기리   1150-5  1150    5       태양   34.460  202308   31
# 22614  전라북도 익산시 낭산면 용기리   1150-5  1150    5       태양   34.460  202308   31
# 22613  전라북도 익산시 낭산면 용기리   1150-5  1150    5       태양   34.460  202308   31
# 22612  전라북도 익산시 낭산면 용기리   1150-5  1150    5       태양   34.460  202308   31
# 22615  전라북도 익산시 낭산면 용기리   1150-5  1150    5       태양   34.460  202308   31
#
# ...

# %%
df[df['거래금액']>40000].sort_values(by='전용금액).loc[ :, ['거래금액', '전용면적','시군구']]
# Out:
#   File "<ipython-input-53-adc6d4e2e4bf>", line 1
#     df[df['거래금액']>40000].sort_values(by='전용금액).loc[ :, ['거래금액', '전용면적','시군구']]
#                                                                            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
df['시군구'].str.contains('강릉')
df[cond]
# Out:
#                    시군구     번지    본번  부번            단지명      전용면적    계약년월  계약일  \
# 1      강원특별자치도 강릉시 견소동    202   202   0           송정한신   84.9450  202308   14
# 4      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   22
# 5      강원특별자치도 강릉시 견소동    289   289   0   송정해변신도브래뉴아파트   84.9900  202308   29
# 6       강원특별자치도 강릉시 교동   1982  1982   0    강릉교동롯데캐슬1단지  163.9852  202308    4
# 7       강원특별자치도 강릉시 교동   1983  1983   0    강릉교동롯데캐슬2단지   84.9855  202308   17
# ...                ...    ...   ...  ..            ...       ...     ...  ...
# 26502     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8090  202308    4
# 26505     충청북도 충주시 호암동   1063  1063   0  충주호암두진하트리움아파트   84.8030  202308   19
# 26506     충청북도 충주시 호암동  547-6   547   6           호반현대   84.9600  202308   12
# 26507     충청북도 충주시 호암동  221-1   221   1     호암리버빌(2단지)   84.6800  202308   10
# 26508     충청북도 충주시 호암동   1191  1191   0        호암힐데스하임   84.9500  202308   21
#
# ...

# %%
dff = df[df['시군구'].str.contains('성수')]
dff
# Out:
#                    시군구       번지   본번   부번        단지명      전용면적    계약년월  계약일  \
# 17714  서울특별시 성동구 성수동1가  685-696  685  696     갤러리아포레  217.8600  202308   11
# 17715  서울특별시 성동구 성수동1가      709  709    0        대우2   84.9700  202308   12
# 17716  서울특별시 성동구 성수동1가  656-234  656  234      서울숲대림   59.8850  202308    1
# 17717  서울특별시 성동구 성수동1가  656-234  656  234      서울숲대림   84.0150  202308    4
# 17718  서울특별시 성동구 성수동1가  656-234  656  234      서울숲대림   59.8850  202308   26
# 17719  서울특별시 성동구 성수동1가      718  718    0       트리마제   84.8213  202308    5
# 17720  서울특별시 성동구 성수동1가      718  718    0       트리마제   84.8213  202308   10
# 17721  서울특별시 성동구 성수동2가      835  835    0     롯데캐슬파크   81.5670  202308    3
# 17722  서울특별시 성동구 성수동2가      838  838    0    성수동두산위브  148.2200  202308    5
# 17723  서울특별시 성동구 성수동2가      286  286    0  성수우방2차아파트   59.8200  202308    5
# 17724  서울특별시 성동구 성수동2가      833  833    0     신성미소지움   59.4000  202308    4
# ...

# %%
dff['거래금액'].mean()
# Out:
# np.float64(257250.0)

# %%
place = input('지역명을 입력하세요')
dff = df[df['시군구'].str.contains(place)]
dff['거래금액'].mean()
# Out:
# 지역명을 입력하세요대전
# np.float64(32022.37168141593)
