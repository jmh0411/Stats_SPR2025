# %% [markdown]
# <a href="https://colab.research.google.com/github/jmh0411/Stats_SPR2025/blob/main/W05_7_20202505.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x = [1,4,9,16,25,36,49,64]
y= [i for i in range (1,9)]
plt.plot(x, y, 'sb')
plt.xlabel('x')
plt.ylabel('y')
plt.title('matplotlib')
plt.show()
